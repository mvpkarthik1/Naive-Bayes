# %%
#importing the required libraries

import pandas as pd

# %%
# uploading the training dataset to train the model

SalaryData_Train = pd.read_csv("SalaryData_Train.csv")

# %%
SalaryData_Train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
#finding the duplicated rows

SalaryData_Train[SalaryData_Train.duplicated()]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 326     33   Private      Bachelors           13   Married-civ-spouse
# 364     27   Private      Bachelors           13        Never-married
# 518     24   Private        HS-grad            9        Never-married
# 525     24   Private        HS-grad            9        Never-married
# 619     33   Private      Bachelors           13   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 30110   47   Private        HS-grad            9   Married-civ-spouse
# 30118   20   Private        HS-grad            9        Never-married
# 30132   22   Private   Some-college           10        Never-married
# 30157   40   Private        HS-grad            9   Married-civ-spouse
# 30159   22   Private        HS-grad            9        Never-married
#
#                occupation    relationship    race      sex  capitalgain  \
# ...

# %%
#removing the duplicated rows

SalaryData_Train.drop_duplicates()
# Out:
#        age          workclass      education  educationno  \
# 0       39          State-gov      Bachelors           13
# 1       50   Self-emp-not-inc      Bachelors           13
# 2       38            Private        HS-grad            9
# 3       53            Private           11th            7
# 4       28            Private      Bachelors           13
# ...    ...                ...            ...          ...
# 30154   53            Private        Masters           14
# 30155   22            Private   Some-college           10
# 30156   27            Private     Assoc-acdm           12
# 30158   58            Private        HS-grad            9
# 30160   52       Self-emp-inc        HS-grad            9
#
#              maritalstatus          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
# importing the label encoder from sklearn library, to label the dataset

from sklearn.preprocessing import LabelEncoder

le= LabelEncoder()

# %%
categ=['workclass','education','maritalstatus','occupation','relationship','race','sex','Salary','native']

SalaryData_Train[categ]= SalaryData_Train[categ].apply(le.fit_transform)

# %%
#plotting the heatmap for training dataset with the help of correlation....

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20,10))
ax= plt.axes()
sns.heatmap(SalaryData_Train.corr(), annot= True, ax= ax)

ax.set_title(" TRAIN DATA HEAT MAP")
plt.show()

# %%
#now importing the testing dataset for testing the model which is build by training with training dataset...

SalaryData_Test=pd.read_csv("SalaryData_Test.csv")
SalaryData_Test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
#finding the duplicated rows

SalaryData_Test[SalaryData_Test.duplicated()]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 551     59   Private        HS-grad            9             Divorced
# 601     32   Private        HS-grad            9   Married-civ-spouse
# 681     40   Private        HS-grad            9   Married-civ-spouse
# 799     24   Private      Bachelors           13        Never-married
# 1044    44   Private    Prof-school           15   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 15043   51   Private        HS-grad            9   Married-civ-spouse
# 15044   22   Private   Some-college           10        Never-married
# 15049   32   Private        HS-grad            9   Married-civ-spouse
# 15052   31   Private        HS-grad            9   Married-civ-spouse
# 15053   25   Private        HS-grad            9        Never-married
#
#                occupation    relationship    race      sex  capitalgain  \
# ...

# %%
#removing the duplicated rows..

SalaryData_Test.drop_duplicates()
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
categ=['workclass','education','maritalstatus','occupation','relationship','race','sex','Salary','native']

SalaryData_Test[categ]=SalaryData_Test[categ].apply(le.fit_transform)

# %%
SalaryData_Test
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
# plotting the heat map for testing dataset

plt.figure(figsize=(20,10))

ax= plt.axes()
sns.heatmap(SalaryData_Test.corr(), annot= True, ax= ax)

ax.set_title("TEST DATA HEAT MAP")
plt.show()

# %%
SalaryData_Test.describe()
# Out:
#                 age     workclass     education   educationno  maritalstatus  \
# count  15060.000000  15060.000000  15060.000000  15060.000000   15060.000000
# mean      38.768327      2.214874     10.272377     10.112749       2.595286
# std       13.380676      0.966422      3.826251      2.558727       1.505336
# min       17.000000      0.000000      0.000000      1.000000       0.000000
# 25%       28.000000      2.000000      9.000000      9.000000       2.000000
# 50%       37.000000      2.000000     11.000000     10.000000       2.000000
# 75%       48.000000      2.000000     12.000000     13.000000       4.000000
# max       90.000000      6.000000     15.000000     16.000000       6.000000
#
#          occupation  relationship          race           sex   capitalgain  \
# count  15060.000000  15060.000000  15060.000000  15060.000000  15060.000000
# mean       5.989044      1.401394      3.683665      0.673772   1120.301594
# ...

# %%
SalaryData_Train.dtypes
# Out:
# age              int64
# workclass        int32
# education        int32
# educationno      int64
# maritalstatus    int32
# occupation       int32
# relationship     int32
# race             int32
# sex              int32
# capitalgain      int64
# capitalloss      int64
# hoursperweek     int64
# native           int32
# Salary           int32
# dtype: object

# %%
tr= SalaryData_Train.values
x_train= tr[:,:-1]
y_train= tr[:,-1]

# %%
tx= SalaryData_Test.values
x_test= tx[:,:-1]
y_test= tx[:,-1]

# %%
from sklearn.naive_bayes import MultinomialNB as NB
naive=NB()

# %%
train_naive= naive.fit(x_train,y_train)

# %%
model_train= train_naive.predict(x_train)

# %%
import numpy as np

train_efficiency= np.mean(y_train==model_train)*100

# %%
train_efficiency
# Out:
# 77.29186698053778

# %%
model_test= train_naive.predict(x_test)

# %%
test_efficiency=np.mean(y_test==model_test)*100

# %%
test_efficiency
# Out:
# 77.49667994687915
